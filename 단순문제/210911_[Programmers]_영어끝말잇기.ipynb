# %%
n=3
words=["tank", "kick", "know", "wheel", "land", "dream", "mother", "robot", "tank"]

# %%
n=5
words=["hello", "observe", "effect", "take", "either", "recognize", "encourage", "ensure", "establish", "hang", "gather", "refer", "reference", "estimate", "executive"]

# %%
n=2
words=["hello", "one", "even", "never", "now", "world", "draw"]
w=["hello","one"]

# %%
#0: [가장 먼저 탈락하는 사람의 번호,그 사람이 자신의 몇 번째 차례에 탈락하는지]
#    탈락자가 안 생기면 [0,0]

# %% [markdown]
# 첫 번째 시도

# %%
import math

# %%
word=words
w=[]

# %%
dict={1:1,2:2,0:3}

# %%
w.append(word.pop(0))
for i in range(len(words)):
  if words[i+1].endswith(words[i][0]) and words[i+1] not in w:
    w.append(word.pop(0))
  else:
    break
if len(words)==len(word):
  s=[0,0]
else:
  s=[dict[i%3],math.trunc(i/3)]

# %% [markdown]
# 두 번째 시도

# %%
# 다른 분 문제 풀이
def solution(n, words):
    for i in range(1, len(words)):
      #규칙에 틀렸을 때를 탈출 조건 틀린 순간의 변수와 return 값이 연관
        if words[i][0] != words[i-1][-1] or words[i] in words[:i] :
            return [(i%n)+1, (i//n)+1]
            # 몇 번째 차례인지 계산해주기 위해서는 현재 인덱스를 n으로 나누고 1을 더해주면 된다.
    return print([0,0])
