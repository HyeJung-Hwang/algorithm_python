# %%
word="I"

# %%
list=["A","E","I","O","U"]

# %%
from itertools import combinations

# %%
dict=[]

# %%
for i in list:
  dict.append(i)
  for j in list:
    dict.append(i+j)
    for k in list:
      dict.append(i+j+k)
      for x in list:
        dict.append(i+j+k+x)
        for y in list:
          dict.append(i+j+k+x+y)

# %%
dict.index(word)
# Out:
# 1562
