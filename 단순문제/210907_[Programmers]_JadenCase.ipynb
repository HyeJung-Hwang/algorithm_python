# %%
#i=영어 문자열
s="3people unFollowed me"

# %% [markdown]
# 첫번째 시도: map 활용

# %%
split=s.split()
word=list(map(split,list))
word[0]=["  "]
word[1:]=[" "," "]
word[0]=list(word[0])[0].uppercase+list(word[0])[1:]
word[1:]=list(map(uppercase,word[1:]))

# %% [markdown]
# 두 번째 시도: 리스트 내포 활용

# %%
split=s.split()

# %%
split
# Out:
# ['3people', 'unFollowed', 'me']

# %%
split[1:] = [i.lower() for i in split[1:]]
split[0]=split[0].capitalize()

# %%
split
# Out:
# ['3people', 'unfollowed', 'me']

# %%
" ".join(split)
# Out:
# '3people unfollowed me'

# %% [markdown]
# 세 번째 시도: 문제 잘 못 이해

# %%
split=s.split()

# %%
split= [i.capitalize() for i in split]

# %%
" ".join(split)
# Out:
# '3people Unfollowed Me'

# %% [markdown]
# 네 번째 시도: s.split(' ')으로 쓰셔야 공백이 여러개일때 분리가 잘 된다

# %%
def solution(s):
    split=s.split(" ") 
    split= [i.capitalize() for i in split]
    return " ".join(split)
