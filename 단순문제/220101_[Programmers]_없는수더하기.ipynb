# %% [markdown]
# 첫 번째 시도: 런타임 에러

# %%
def solution(numbers):
    answer = -1
    one9 = list(range(1,10))
    for i in numbers:
        one9.remove(i)
    answer = sum(one9)
    return answer

# %% [markdown]
# 두 번째 시도: 성공!

# %%
def solution(numbers):
    
    answer = 0
    answer = 45 - sum(numbers)

    return answer
