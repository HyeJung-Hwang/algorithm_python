# %%
priorities=[2,1,3,2]
location=2

# %%
answer=0

# %%
array1=[c for c in range(len(priorities))] #리스트의 index로 만든 리스트 
array2=priorities.copy() # 값 저장
i=0

# %%
while True:
  if array2[i] < max(array2[i+1:]):
            array1.append(array1.pop(i)) #리스트 앞에꺼 빼서 뒤로
            array2.append(array2.pop(i))
  else:
        i += 1

  if array2 == sorted(array2, reverse=True):
      break

# %%
array1.index(location) + 1
