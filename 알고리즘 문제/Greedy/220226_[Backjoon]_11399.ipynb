# %%
import sys
n = int(sys.stdin.readline())
num_list = list(map( int, sys.stdin.readline().split() ))
sum = 0
ans = 0 

for i in sorted(num_list): # 1 2 3 3 4

    temp = i # 1 # 2
    sum += temp  # 1 # 3
    ans += sum 
    

print(ans)
